# %% [markdown]
# # 20251212-Analysis

# %%
# !pip install nucleus-cdk | tail -n2
# Out:
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.*->jupyter-bokeh<5.0.0,>=4.0.5->nucleus-cdk) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/conda/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.*->jupyter-bokeh<5.0.0,>=4.0.5->nucleus-cdk) (0.2.3)

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2
    
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Import the cdk platereader module
from cdk.analysis.cytosol import platereader as pr
import warnings

warnings.filterwarnings('ignore')

# Set up plotting
pr.plot_setup()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load Data

# %%
# Specify file paths
data_file = "20251212-cytation3-pure-timecourse-gfp-EXPERIMENT-biotek-cdk.txt"
platemap_file = "20251212-ClpXP.csv"


# Load data
data, platemap = pr.load_platereader_data(
    data_file=data_file,
    platemap_file=platemap_file,
    platereader="biotek-cdk"  # Options: "cytation", "envision", "biotek-cdk"
)

# Checkout first few rows
data.head()
# Out:
#              Time Well    Data Row  Column       Read          Clock Time  \
# 0 0 days 00:00:00   B1   35.00   B       1  GFP-F-G35 2025-12-12 11:15:00
# 1 0 days 00:05:00   B1   37.00   B       1  GFP-F-G35 2025-12-12 11:20:00
# 2 0 days 00:10:00   B1  234.00   B       1  GFP-F-G35 2025-12-12 11:25:00
# 3 0 days 00:15:00   B1 1008.00   B       1  GFP-F-G35 2025-12-12 11:30:00
# 4 0 days 00:20:00   B1 2369.00   B       1  GFP-F-G35 2025-12-12 11:35:00
#
#   Experiment                                               Name  CP
# 0      ClpXP  0.35 ng/ul ClpX DNA + 0.35 ng/ul ClpP DNA+  3....   1
# 1      ClpXP  0.35 ng/ul ClpX DNA + 0.35 ng/ul ClpP DNA+  3....   1
# 2      ClpXP  0.35 ng/ul ClpX DNA + 0.35 ng/ul ClpP DNA+  3....   1
# 3      ClpXP  0.35 ng/ul ClpX DNA + 0.35 ng/ul ClpP DNA+  3....   1
# 4      ClpXP  0.35 ng/ul ClpX DNA + 0.35 ng/ul ClpP DNA+  3....   1

# %% [markdown]
# ## Plot Raw Curves

# %%
#| label: 20251212-kinetics

g = pr.plot_curves(data=data)
