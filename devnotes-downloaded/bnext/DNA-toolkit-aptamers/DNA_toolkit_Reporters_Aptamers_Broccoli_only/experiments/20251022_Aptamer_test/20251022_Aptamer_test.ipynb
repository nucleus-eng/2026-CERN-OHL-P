# %%
from cdk.analysis.cytosol import platereader as pr
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
pr.plot_setup()

# %%
data, platemap = pr.load_platereader_data(
    data_file="20251022_Aptamer_test.txt", 
    platemap_file="20251022_Aptamer_test_platemap.tsv", 
    platereader="biotek-cdk"
)
data.to_csv('20251022_aptamer_test_data.csv')

# %%
pr.plot_curves(data, col="Name", hue="Well", estimator=None)

# %%
pr.plot_curves(data)
