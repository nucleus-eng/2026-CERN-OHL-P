# %%
from cdk.analysis.cytosol import platereader as pr
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
pr.plot_setup()

# %%
data, platemap = pr.load_platereader_data(
    data_file="20251024_Aptamer_test.txt", 
    platemap_file="20251024_Aptamer_test_platemap.tsv", 
    platereader="biotek-cdk"
)
data.to_csv('20251024_aptamer_test_data.csv')
print(data)
# Out:
# No data loaded: section potentially unrecognized: TO1-Biotin
#                 Time Well   Data Row  Column        Read    Plate  \
# 0    0 days 00:00:00   D3   1164   D       3  TO1-Biotin  Plate 1
# 1    0 days 00:05:00   D3    901   D       3  TO1-Biotin  Plate 1
# 2    0 days 00:10:00   D3    764   D       3  TO1-Biotin  Plate 1
# 3    0 days 00:15:00   D3    684   D       3  TO1-Biotin  Plate 1
# 4    0 days 00:20:00   D3    704   D       3  TO1-Biotin  Plate 1
# ...              ...  ...    ...  ..     ...         ...      ...
# 1090 0 days 05:40:00  H11  13335   H      11  TO1-Biotin  Plate 1
# 1091 0 days 05:45:00  H11  12959   H      11  TO1-Biotin  Plate 1
# 1092 0 days 05:50:00  H11  12811   H      11  TO1-Biotin  Plate 1
# 1093 0 days 05:55:00  H11  12750   H      11  TO1-Biotin  Plate 1
# 1094 0 days 06:00:00  H11  12687   H      11  TO1-Biotin  Plate 1
#
#               Clock Time  Sample #                Name
# 0    2025-10-24 16:03:14         1            Negative
# 1    2025-10-24 16:08:14         1            Negative
# 2    2025-10-24 16:13:14         1            Negative
# 3    2025-10-24 16:18:14         1            Negative
# 4    2025-10-24 16:23:14         1            Negative
# ...                  ...       ...                 ...
# 1090 2025-10-24 21:43:14         5  1430 nm TO1-Biotin
# 1091 2025-10-24 21:48:14         5  1430 nm TO1-Biotin
# 1092 2025-10-24 21:53:14         5  1430 nm TO1-Biotin
# 1093 2025-10-24 21:58:14         5  1430 nm TO1-Biotin
# 1094 2025-10-24 22:03:14         5  1430 nm TO1-Biotin
#
# [1095 rows x 10 columns]

# %%
pr.plot_curves(data)
