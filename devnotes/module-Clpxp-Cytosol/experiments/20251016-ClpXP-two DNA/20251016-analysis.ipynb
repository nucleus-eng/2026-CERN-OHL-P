# %% [markdown]
# # 20251016-Analysis

# %%
# !pip install nucleus-cdk==0.5.0rc2 | tail -n2
# Out:
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.*->jupyter-bokeh<5.0.0,>=4.0.5->nucleus-cdk) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/conda/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.*->jupyter-bokeh<5.0.0,>=4.0.5->nucleus-cdk) (0.2.3)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from cdk.analysis.cytosol import platereader as pr
import warnings

warnings.filterwarnings('ignore')

# Initialize plotting
pr.plot_setup()

# %% [markdown]
# # Load the data
#
# Provide a CSV file containing the data, and a platemap. This function returns both the data with the plate map mapped to it, and the platemap by itself, which is useful for certain tasks.

# %%
data_file = "20251016-cytation3-pure-timecourse-gfp-EXPERIMENT-biotek-cdk.txt"
platemap_file = "20251017-ClpXP-2.csv"

data, platemap = pr.load_platereader_data(data_file, platemap_file)

# %% [markdown]
# # Basic Analysis

# %% [markdown]
# ## Curves
# Curves of RFU over time, by named sample.

# %%
#| label: 20251016-kinetics

pr.plot_curves(data);
